# %% [markdown]
# # Office Supplies Store - Student Practice Notebook
#
# Dataset file: `10_office_supplies_store.csv`
#
# Solve each task in the empty code cell below it.

# %% [markdown]
# ## Task 1
#
# Load the dataset into a pandas DataFrame.

# %%
import pandas as pd

# %%
df = pd.read_csv("10_office_supplies_store.csv",header = 0)

# %% [markdown]
# ## Task 2
#
# Display the first 10 rows of the DataFrame.

# %%
df.head(10)
# Out:
#       Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# 0  10ORD100522  2025-10-19       Freelancer    South       Stationery
# 1  10ORD100738  2024-01-12          Startup    North        Furniture
# 2  10ORD100741  2025-06-25           School    South           Pantry
# 3  10ORD100661  2024-12-29       Enterprise     West         Printing
# 4  10ORD100412  2025-06-19       Enterprise     East      Electronics
# 5  10ORD100679  2025-08-21          Startup  Central        Furniture
# 6  10ORD100627  2025-04-08       Enterprise     East         Printing
# 7  10ORD100514  2024-01-20          Startup    South      Electronics
# 8  10ORD100860  2024-07-09       Freelancer    North        Furniture
# 9  10ORD100137  2025-06-11       Enterprise    North           Pantry
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0            UPI        10    15063.47                17    125026.80
# 1  Bank Transfer         2     9166.28                27     13382.77
# 2  Bank Transfer        10    24589.43                27    179502.84
# 3    Credit Card         1    17994.69                 7     16735.06
# 4     Debit Card        20      307.87                22      4802.77
# 5            UPI         2    16240.90                16     27284.71
# 6    Net Banking         1     8855.07                10      7969.56
# 7  Bank Transfer         5    23698.47                25     88869.26
# 8    Credit Card         2     2966.99                17      4925.20
# 9            UPI         1      249.84                24       189.88

# %% [markdown]
# ## Task 3
#
# Display the last 7 rows of the DataFrame.

# %%
df.tail(7)
# Out:
#         Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# 993  10ORD100701  2025-07-02       Enterprise  Central        Furniture
# 994  10ORD100072  2025-07-20           School     East        Furniture
# 995  10ORD100107  2024-03-09       Freelancer     West        Furniture
# 996  10ORD100271  2024-02-28           School     West        Furniture
# 997  10ORD100861  2024-07-03       Freelancer     East      Electronics
# 998  10ORD100436  2025-12-27       Freelancer    South         Printing
# 999  10ORD100103  2024-09-21          Startup     East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 993     Debit Card         1    20756.01                 5     19718.21
# 994     Debit Card         2    11096.09                18     18197.59
# 995            UPI         4      965.76                28      2781.39
# 996    Credit Card         4    20712.50                18     67937.00
# 997    Credit Card         2    17613.75                27     25716.08
# 998    Credit Card         5    18031.72                 5     85650.67
# 999     Debit Card         4    22269.54                 8     81951.91

# %% [markdown]
# ## Task 4
#
# Check the shape of the DataFrame.

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## Task 5
#
# List all column names.

# %%
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Percent',
#  'Order_Value']

# %% [markdown]
# ## Task 6
#
# Check the data types of all columns.

# %%
df.dtypes
# Out:
# Order_ID                str
# Order_Date              str
# Customer_Segment        str
# Region                  str
# Product_Category        str
# Payment_Method          str
# Quantity              int64
# Unit_Price          float64
# Discount_Percent      int64
# Order_Value         float64
# dtype: object

# %% [markdown]
# ## Task 7
#
# Display basic information using info().

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   str
#  1   Order_Date        1000 non-null   str
#  2   Customer_Segment  1000 non-null   str
#  3   Region            1000 non-null   str
#  4   Product_Category  1000 non-null   str
#  5   Payment_Method    1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Discount_Percent  1000 non-null   int64
#  9   Order_Value       1000 non-null   float64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 78.3 KB

# %% [markdown]
# ## Task 8
#
# Generate summary statistics for numerical columns.

# %%
df.describe()
# Out:
#          Quantity    Unit_Price  Discount_Percent    Order_Value
# count  1000.00000   1000.000000         1000.0000    1000.000000
# mean      5.32600  12583.022980           14.1030   56478.788600
# std       5.82904   7271.797901            8.3459   77616.146203
# min       1.00000     29.210000            0.0000      49.070000
# 25%       2.00000   6324.635000            7.0000   11879.745000
# 50%       3.00000  12760.985000           14.0000   25560.280000
# 75%       5.00000  18970.367500           21.0000   64649.995000
# max      20.00000  24991.950000           28.0000  467023.610000

# %% [markdown]
# ## Task 9
#
# Generate summary statistics for categorical columns.

# %%
df.describe(include='object')
# Out:
# C:\Users\Nallabothula.Naidu\AppData\Local\Temp\ipykernel_10692\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#            Order_ID  Order_Date Customer_Segment Region Product_Category  \
# count          1000        1000             1000   1000             1000
# unique         1000         548                4      5                5
# top     10ORD100522  2024-09-14       Enterprise  North        Furniture
# freq              1           5              260    211              208
#
#        Payment_Method
# count            1000
# unique              5
# top       Net Banking
# freq              234

# %% [markdown]
# ## Task 10
#
# Check whether the DataFrame contains any missing values.

# %%
df.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# ## Task 11
#
# Count the missing values in each column.

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Segment    0
# Region              0
# Product_Category    0
# Payment_Method      0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Order_Value         0
# dtype: int64

# %% [markdown]
# ## Task 12
#
# Check whether there are any duplicate rows.

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ## Task 13
#
# Count the duplicate rows in the DataFrame.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Task 14
#
# Drop duplicate rows if any exist.

# %%
df.drop_duplicates()
# Out:
#         Order_ID  Order_Date Customer_Segment Region Product_Category  \
# 0    10ORD100522  2025-10-19       Freelancer  South       Stationery
# 1    10ORD100738  2024-01-12          Startup  North        Furniture
# 2    10ORD100741  2025-06-25           School  South           Pantry
# 3    10ORD100661  2024-12-29       Enterprise   West         Printing
# 4    10ORD100412  2025-06-19       Enterprise   East      Electronics
# ..           ...         ...              ...    ...              ...
# 995  10ORD100107  2024-03-09       Freelancer   West        Furniture
# 996  10ORD100271  2024-02-28           School   West        Furniture
# 997  10ORD100861  2024-07-03       Freelancer   East      Electronics
# 998  10ORD100436  2025-12-27       Freelancer  South         Printing
# 999  10ORD100103  2024-09-21          Startup   East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0              UPI        10    15063.47                17    125026.80
# 1    Bank Transfer         2     9166.28                27     13382.77
# 2    Bank Transfer        10    24589.43                27    179502.84
# 3      Credit Card         1    17994.69                 7     16735.06
# 4       Debit Card        20      307.87                22      4802.77
# ..             ...       ...         ...               ...          ...
# 995            UPI         4      965.76                28      2781.39
# 996    Credit Card         4    20712.50                18     67937.00
# 997    Credit Card         2    17613.75                27     25716.08
# 998    Credit Card         5    18031.72                 5     85650.67
# 999     Debit Card         4    22269.54                 8     81951.91
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## Task 15
#
# Convert the Order_Date column to datetime format.

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   str
#  1   Order_Date        1000 non-null   datetime64[us]
#  2   Customer_Segment  1000 non-null   str
#  3   Region            1000 non-null   str
#  4   Product_Category  1000 non-null   str
#  5   Payment_Method    1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Discount_Percent  1000 non-null   int64
#  9   Order_Value       1000 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(5)
# memory usage: 78.3 KB

# %% [markdown]
# ## Task 16
#
# Extract only the year from Order_Date into a new column named Order_Year.

# %%
df["Order_Year"] = df["Order_Date"].dt.year

# %% [markdown]
# ## Task 17
#
# Extract the month name from Order_Date into a new column named Order_Month.

# %%
df["Order_Month"] = df["Order_Date"].dt.month

# %%
df[["Order_Month","Order_Year"]]
# Out:
#      Order_Month  Order_Year
# 0             10        2025
# 1              1        2024
# 2              6        2025
# 3             12        2024
# 4              6        2025
# ..           ...         ...
# 995            3        2024
# 996            2        2024
# 997            7        2024
# 998           12        2025
# 999            9        2024
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Task 18
#
# Extract the weekday name from Order_Date into a new column named Order_Day.

# %%
df["Order_Day"] = df["Order_Date"].dt.day

# %% [markdown]
# ## Task 19
#
# Display a random sample of 12 rows.

# %%
df.sample(12)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 944  10ORD100485 2025-02-15       Enterprise     West         Printing
# 723  10ORD100280 2024-07-03       Freelancer     East           Pantry
# 592  10ORD100668 2024-12-10       Freelancer    South       Stationery
# 278  10ORD100082 2025-01-14       Freelancer    South           Pantry
# 948  10ORD100244 2024-01-25       Freelancer    South         Printing
# 644  10ORD100375 2025-12-11           School     West         Printing
# 467  10ORD100418 2024-01-17           School    North       Stationery
# 516  10ORD100223 2024-10-12          Startup  Central           Pantry
# 414  10ORD100818 2024-01-28          Startup    South         Printing
# 902  10ORD100270 2025-08-23          Startup    South       Stationery
# 142  10ORD100722 2024-12-14       Enterprise    North       Stationery
# 560  10ORD100196 2025-10-10           School  Central         Printing
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 944            UPI        10     6989.56                24     53120.66
# 723            UPI         1     5674.58                17      4709.90
# 592  Bank Transfer         2    19659.31                27     28702.59
# 278     Debit Card         2    16170.24                17     26842.60
# 948            UPI         3    21985.07                 2     64636.11
# 644    Net Banking        10    16530.49                11    147121.36
# 467  Bank Transfer         3    14352.32                18     35306.71
# 516            UPI        10    18840.85                17    156379.06
# 414    Net Banking        10    19702.45                20    157619.60
# 902  Bank Transfer        10     1833.97                23     14121.57
# 142     Debit Card         2     5887.12                19      9537.13
# 560  Bank Transfer         3    17350.18                 6     48927.51
#
#      Order_Year  Order_Month  Order_Day
# 944        2025            2         15
# 723        2024            7          3
# 592        2024           12         10
# 278        2025            1         14
# 948        2024            1         25
# 644        2025           12         11
# 467        2024            1         17
# 516        2024           10         12
# 414        2024            1         28
# 902        2025            8         23
# 142        2024           12         14
# 560        2025           10         10

# %% [markdown]
# ## Task 20
#
# Rename Discount_Percent to Discount.

# %%
df.rename(columns = {"Discount_Percent":"Discount"})
# Out:
#         Order_ID Order_Date Customer_Segment Region Product_Category  \
# 0    10ORD100522 2025-10-19       Freelancer  South       Stationery
# 1    10ORD100738 2024-01-12          Startup  North        Furniture
# 2    10ORD100741 2025-06-25           School  South           Pantry
# 3    10ORD100661 2024-12-29       Enterprise   West         Printing
# 4    10ORD100412 2025-06-19       Enterprise   East      Electronics
# ..           ...        ...              ...    ...              ...
# 995  10ORD100107 2024-03-09       Freelancer   West        Furniture
# 996  10ORD100271 2024-02-28           School   West        Furniture
# 997  10ORD100861 2024-07-03       Freelancer   East      Electronics
# 998  10ORD100436 2025-12-27       Freelancer  South         Printing
# 999  10ORD100103 2024-09-21          Startup   East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount  Order_Value  Order_Year  \
# 0              UPI        10    15063.47        17    125026.80        2025
# 1    Bank Transfer         2     9166.28        27     13382.77        2024
# 2    Bank Transfer        10    24589.43        27    179502.84        2025
# 3      Credit Card         1    17994.69         7     16735.06        2024
# 4       Debit Card        20      307.87        22      4802.77        2025
# ..             ...       ...         ...       ...          ...         ...
# 995            UPI         4      965.76        28      2781.39        2024
# 996    Credit Card         4    20712.50        18     67937.00        2024
# 997    Credit Card         2    17613.75        27     25716.08        2024
# 998    Credit Card         5    18031.72         5     85650.67        2025
# 999     Debit Card         4    22269.54         8     81951.91        2024
#
#      Order_Month  Order_Day
# 0             10         19
# 1              1         12
# 2              6         25
# 3             12         29
# 4              6         19
# ..           ...        ...
# 995            3          9
# 996            2         28
# 997            7          3
# 998           12         27
# 999            9         21
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 21
#
# Change the column name back from Discount to Discount_Percent.

# %%
df.rename(columns = {"Discount":"Discount_Percent"})
# Out:
#         Order_ID Order_Date Customer_Segment Region Product_Category  \
# 0    10ORD100522 2025-10-19       Freelancer  South       Stationery
# 1    10ORD100738 2024-01-12          Startup  North        Furniture
# 2    10ORD100741 2025-06-25           School  South           Pantry
# 3    10ORD100661 2024-12-29       Enterprise   West         Printing
# 4    10ORD100412 2025-06-19       Enterprise   East      Electronics
# ..           ...        ...              ...    ...              ...
# 995  10ORD100107 2024-03-09       Freelancer   West        Furniture
# 996  10ORD100271 2024-02-28           School   West        Furniture
# 997  10ORD100861 2024-07-03       Freelancer   East      Electronics
# 998  10ORD100436 2025-12-27       Freelancer  South         Printing
# 999  10ORD100103 2024-09-21          Startup   East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0              UPI        10    15063.47                17    125026.80
# 1    Bank Transfer         2     9166.28                27     13382.77
# 2    Bank Transfer        10    24589.43                27    179502.84
# 3      Credit Card         1    17994.69                 7     16735.06
# 4       Debit Card        20      307.87                22      4802.77
# ..             ...       ...         ...               ...          ...
# 995            UPI         4      965.76                28      2781.39
# 996    Credit Card         4    20712.50                18     67937.00
# 997    Credit Card         2    17613.75                27     25716.08
# 998    Credit Card         5    18031.72                 5     85650.67
# 999     Debit Card         4    22269.54                 8     81951.91
#
#      Order_Year  Order_Month  Order_Day
# 0          2025           10         19
# 1          2024            1         12
# 2          2025            6         25
# 3          2024           12         29
# 4          2025            6         19
# ..          ...          ...        ...
# 995        2024            3          9
# 996        2024            2         28
# 997        2024            7          3
# 998        2025           12         27
# 999        2024            9         21
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 22
#
# Set Order_ID as the index.

# %%
df.set_index('Order_ID')
# Out:
#             Order_Date Customer_Segment Region Product_Category  \
# Order_ID
# 10ORD100522 2025-10-19       Freelancer  South       Stationery
# 10ORD100738 2024-01-12          Startup  North        Furniture
# 10ORD100741 2025-06-25           School  South           Pantry
# 10ORD100661 2024-12-29       Enterprise   West         Printing
# 10ORD100412 2025-06-19       Enterprise   East      Electronics
# ...                ...              ...    ...              ...
# 10ORD100107 2024-03-09       Freelancer   West        Furniture
# 10ORD100271 2024-02-28           School   West        Furniture
# 10ORD100861 2024-07-03       Freelancer   East      Electronics
# 10ORD100436 2025-12-27       Freelancer  South         Printing
# 10ORD100103 2024-09-21          Startup   East      Electronics
#
#             Payment_Method  Quantity  Unit_Price  Discount_Percent  \
# Order_ID
# 10ORD100522            UPI        10    15063.47                17
# 10ORD100738  Bank Transfer         2     9166.28                27
# 10ORD100741  Bank Transfer        10    24589.43                27
# 10ORD100661    Credit Card         1    17994.69                 7
# 10ORD100412     Debit Card        20      307.87                22
# ...                    ...       ...         ...               ...
# 10ORD100107            UPI         4      965.76                28
# 10ORD100271    Credit Card         4    20712.50                18
# 10ORD100861    Credit Card         2    17613.75                27
# 10ORD100436    Credit Card         5    18031.72                 5
# 10ORD100103     Debit Card         4    22269.54                 8
#
#              Order_Value  Order_Year  Order_Month  Order_Day
# Order_ID
# 10ORD100522    125026.80        2025           10         19
# 10ORD100738     13382.77        2024            1         12
# 10ORD100741    179502.84        2025            6         25
# 10ORD100661     16735.06        2024           12         29
# 10ORD100412      4802.77        2025            6         19
# ...                  ...         ...          ...        ...
# 10ORD100107      2781.39        2024            3          9
# 10ORD100271     67937.00        2024            2         28
# 10ORD100861     25716.08        2024            7          3
# 10ORD100436     85650.67        2025           12         27
# 10ORD100103     81951.91        2024            9         21
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Task 23
#
# Reset the index back to default integer index.

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ## Task 24
#
# Sort the DataFrame by Order_Value in descending order.

# %%
df.sort_values('Order_Value', ascending=False)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 427  10ORD100062 2025-11-17       Enterprise  Central      Electronics
# 921  10ORD100035 2024-11-13          Startup     East      Electronics
# 665  10ORD100227 2025-10-18          Startup    South       Stationery
# 386  10ORD100501 2025-07-13          Startup     East      Electronics
# 940  10ORD100841 2024-06-06       Freelancer     East       Stationery
# ..           ...        ...              ...      ...              ...
# 645  10ORD100470 2024-02-06       Freelancer     East         Printing
# 9    10ORD100137 2025-06-11       Enterprise    North           Pantry
# 413  10ORD100265 2025-04-08          Startup     East         Printing
# 613  10ORD100713 2025-04-23       Enterprise     East        Furniture
# 618  10ORD100985 2024-01-03       Freelancer  Central           Pantry
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 427  Bank Transfer        20    24580.19                 5    467023.61
# 921    Net Banking        20    23755.17                 8    437095.13
# 665  Bank Transfer        20    22317.62                 9    406180.68
# 386    Net Banking        20    20519.62                 3    398080.63
# 940            UPI        20    21601.38                 8    397465.39
# ..             ...       ...         ...               ...          ...
# 645  Bank Transfer         3       83.24                13       217.26
# 9              UPI         1      249.84                24       189.88
# 413            UPI         1      180.68                 4       173.45
# 613    Net Banking         2       54.65                13        95.09
# 618    Net Banking         2       29.21                16        49.07
#
#      Order_Year  Order_Month  Order_Day
# 427        2025           11         17
# 921        2024           11         13
# 665        2025           10         18
# 386        2025            7         13
# 940        2024            6          6
# ..          ...          ...        ...
# 645        2024            2          6
# 9          2025            6         11
# 413        2025            4          8
# 613        2025            4         23
# 618        2024            1          3
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 25
#
# Sort the DataFrame by Quantity ascending and Unit_Price descending.

# %%
df.sort_values(by=['Quantity', 'Unit_Price'], ascending=[True, False])
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 700  10ORD100789 2025-07-21           School     East       Stationery
# 182  10ORD100378 2025-07-14       Freelancer  Central      Electronics
# 137  10ORD100216 2025-08-22           School  Central        Furniture
# 211  10ORD100142 2024-09-20           School     West      Electronics
# 339  10ORD100533 2024-11-22           School    North         Printing
# ..           ...        ...              ...      ...              ...
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
# 556  10ORD100370 2024-03-25           School     East       Stationery
# 632  10ORD100284 2025-11-13           School    South        Furniture
# 766  10ORD100374 2024-07-17       Freelancer    North      Electronics
# 4    10ORD100412 2025-06-19       Enterprise     East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 700    Net Banking         1    24838.88                 3     24093.71
# 182    Net Banking         1    24507.86                10     22057.07
# 137  Bank Transfer         1    24491.38                 7     22776.98
# 211  Bank Transfer         1    24436.81                 6     22970.60
# 339  Bank Transfer         1    24377.75                27     17795.76
# ..             ...       ...         ...               ...          ...
# 357    Net Banking        20      797.61                11     14197.46
# 556    Credit Card        20      707.07                 7     13151.50
# 632    Net Banking        20      541.60                25      8124.00
# 766            UPI        20      343.28                21      5423.82
# 4       Debit Card        20      307.87                22      4802.77
#
#      Order_Year  Order_Month  Order_Day
# 700        2025            7         21
# 182        2025            7         14
# 137        2025            8         22
# 211        2024            9         20
# 339        2024           11         22
# ..          ...          ...        ...
# 357        2024            5          3
# 556        2024            3         25
# 632        2025           11         13
# 766        2024            7         17
# 4          2025            6         19
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 26
#
# Filter all rows where Region is North.

# %%
cond = df["Region"] == "North"
df[cond]
# Out:
#         Order_ID Order_Date Customer_Segment Region Product_Category  \
# 339  10ORD100533 2024-11-22           School  North         Printing
# 102  10ORD100937 2025-02-17          Startup  North      Electronics
# 468  10ORD100526 2025-10-17           School  North         Printing
# 238  10ORD100193 2024-02-27       Enterprise  North           Pantry
# 384  10ORD100221 2025-10-31           School  North         Printing
# ..           ...        ...              ...    ...              ...
# 171  10ORD100480 2024-09-16       Enterprise  North        Furniture
# 585  10ORD100408 2024-12-11          Startup  North       Stationery
# 389  10ORD100775 2025-06-17       Enterprise  North         Printing
# 584  10ORD100809 2024-01-13          Startup  North           Pantry
# 766  10ORD100374 2024-07-17       Freelancer  North      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 339  Bank Transfer         1    24377.75                27     17795.76
# 102            UPI         1    24251.24                11     21583.60
# 468     Debit Card         1    24131.04                 3     23407.11
# 238  Bank Transfer         1    24083.21                21     19025.74
# 384  Bank Transfer         1    22586.65                 6     21231.45
# ..             ...       ...         ...               ...          ...
# 171    Credit Card        20     2922.28                28     42080.83
# 585     Debit Card        20     2018.78                22     31492.97
# 389     Debit Card        20     1969.49                 6     37026.41
# 584            UPI        20     1820.00                28     26208.00
# 766            UPI        20      343.28                21      5423.82
#
#      Order_Year  Order_Month  Order_Day
# 339        2024           11         22
# 102        2025            2         17
# 468        2025           10         17
# 238        2024            2         27
# 384        2025           10         31
# ..          ...          ...        ...
# 171        2024            9         16
# 585        2024           12         11
# 389        2025            6         17
# 584        2024            1         13
# 766        2024            7         17
#
# [211 rows x 13 columns]

# %% [markdown]
# ## Task 27
#
# Filter all rows where Payment_Method is UPI.

# %%
cond = df["Payment_Method"] == "UPI"
df[cond]
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 102  10ORD100937 2025-02-17          Startup    North      Electronics
# 786  10ORD100954 2025-10-15           School  Central       Stationery
# 900  10ORD100816 2024-10-01           School     West        Furniture
# 196  10ORD100333 2024-03-03       Enterprise  Central        Furniture
# 638  10ORD100438 2025-07-04       Enterprise     East        Furniture
# ..           ...        ...              ...      ...              ...
# 956  10ORD100476 2025-04-12       Freelancer    South        Furniture
# 510  10ORD100258 2024-01-01       Enterprise    North      Electronics
# 584  10ORD100809 2024-01-13          Startup    North           Pantry
# 228  10ORD100905 2024-03-23           School  Central      Electronics
# 766  10ORD100374 2024-07-17       Freelancer    North      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 102            UPI         1    24251.24                11     21583.60
# 786            UPI         1    24135.53                 3     23411.46
# 900            UPI         1    22598.88                11     20113.00
# 196            UPI         1    21645.26                12     19047.83
# 638            UPI         1    21380.05                15     18173.04
# ..             ...       ...         ...               ...          ...
# 956            UPI        20     3957.84                23     60950.74
# 510            UPI        20     3282.67                26     48583.52
# 584            UPI        20     1820.00                28     26208.00
# 228            UPI        20     1419.02                 2     27812.79
# 766            UPI        20      343.28                21      5423.82
#
#      Order_Year  Order_Month  Order_Day
# 102        2025            2         17
# 786        2025           10         15
# 900        2024           10          1
# 196        2024            3          3
# 638        2025            7          4
# ..          ...          ...        ...
# 956        2025            4         12
# 510        2024            1          1
# 584        2024            1         13
# 228        2024            3         23
# 766        2024            7         17
#
# [198 rows x 13 columns]

# %% [markdown]
# ## Task 28
#
# Filter all rows where Quantity is greater than 3.

# %%
cond = df["Quantity"] > 3 
df[cond]
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 769  10ORD100234 2025-10-03       Enterprise  Central           Pantry
# 225  10ORD100003 2025-08-29       Freelancer     West           Pantry
# 226  10ORD100545 2024-12-23           School    North         Printing
# 472  10ORD100931 2025-06-13          Startup    South       Stationery
# 10   10ORD100812 2024-09-14       Enterprise    South       Stationery
# ..           ...        ...              ...      ...              ...
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
# 556  10ORD100370 2024-03-25           School     East       Stationery
# 632  10ORD100284 2025-11-13           School    South        Furniture
# 766  10ORD100374 2024-07-17       Freelancer    North      Electronics
# 4    10ORD100412 2025-06-19       Enterprise     East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 769            UPI         4    24896.88                18     81661.77
# 225            UPI         4    24887.14                25     74661.42
# 226    Credit Card         4    24823.40                 2     97307.73
# 472    Credit Card         4    24629.75                28     70933.68
# 10             UPI         4    24397.60                24     74168.70
# ..             ...       ...         ...               ...          ...
# 357    Net Banking        20      797.61                11     14197.46
# 556    Credit Card        20      707.07                 7     13151.50
# 632    Net Banking        20      541.60                25      8124.00
# 766            UPI        20      343.28                21      5423.82
# 4       Debit Card        20      307.87                22      4802.77
#
#      Order_Year  Order_Month  Order_Day
# 769        2025           10          3
# 225        2025            8         29
# 226        2024           12         23
# 472        2025            6         13
# 10         2024            9         14
# ..          ...          ...        ...
# 357        2024            5          3
# 556        2024            3         25
# 632        2025           11         13
# 766        2024            7         17
# 4          2025            6         19
#
# [448 rows x 13 columns]

# %% [markdown]
# ## Task 29
#
# Filter all rows where Order_Value is above 5000.

# %%
cond = df["Order_Value"] > 5000 
df[cond]
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 700  10ORD100789 2025-07-21           School     East       Stationery
# 182  10ORD100378 2025-07-14       Freelancer  Central      Electronics
# 137  10ORD100216 2025-08-22           School  Central        Furniture
# 211  10ORD100142 2024-09-20           School     West      Electronics
# 339  10ORD100533 2024-11-22           School    North         Printing
# ..           ...        ...              ...      ...              ...
# 799  10ORD100847 2025-12-24       Enterprise     West         Printing
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
# 556  10ORD100370 2024-03-25           School     East       Stationery
# 632  10ORD100284 2025-11-13           School    South        Furniture
# 766  10ORD100374 2024-07-17       Freelancer    North      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 700    Net Banking         1    24838.88                 3     24093.71
# 182    Net Banking         1    24507.86                10     22057.07
# 137  Bank Transfer         1    24491.38                 7     22776.98
# 211  Bank Transfer         1    24436.81                 6     22970.60
# 339  Bank Transfer         1    24377.75                27     17795.76
# ..             ...       ...         ...               ...          ...
# 799     Debit Card        20     1141.91                28     16443.50
# 357    Net Banking        20      797.61                11     14197.46
# 556    Credit Card        20      707.07                 7     13151.50
# 632    Net Banking        20      541.60                25      8124.00
# 766            UPI        20      343.28                21      5423.82
#
#      Order_Year  Order_Month  Order_Day
# 700        2025            7         21
# 182        2025            7         14
# 137        2025            8         22
# 211        2024            9         20
# 339        2024           11         22
# ..          ...          ...        ...
# 799        2025           12         24
# 357        2024            5          3
# 556        2024            3         25
# 632        2025           11         13
# 766        2024            7         17
#
# [910 rows x 13 columns]

# %% [markdown]
# ## Task 30
#
# Filter rows where Discount_Percent is between 10 and 20.

# %%
df[(df['Discount_Percent'] >= 10) & (df['Discount_Percent'] <= 20)]
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 182  10ORD100378 2025-07-14       Freelancer  Central      Electronics
# 102  10ORD100937 2025-02-17          Startup    North      Electronics
# 362  10ORD100136 2025-12-24           School     East         Printing
# 173  10ORD100990 2025-02-09       Freelancer    South      Electronics
# 900  10ORD100816 2024-10-01           School     West        Furniture
# ..           ...        ...              ...      ...              ...
# 203  10ORD100558 2024-08-04          Startup    South         Printing
# 758  10ORD100442 2025-05-19          Startup  Central           Pantry
# 130  10ORD100600 2024-04-16          Startup     West      Electronics
# 549  10ORD100127 2024-02-24       Freelancer  Central         Printing
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 182    Net Banking         1    24507.86                10     22057.07
# 102            UPI         1    24251.24                11     21583.60
# 362    Net Banking         1    23352.57                10     21017.31
# 173    Credit Card         1    22871.47                20     18297.18
# 900            UPI         1    22598.88                11     20113.00
# ..             ...       ...         ...               ...          ...
# 203    Credit Card        20     3683.57                17     61147.26
# 758     Debit Card        20     3080.89                20     49294.24
# 130    Net Banking        20     1227.06                18     20123.78
# 549  Bank Transfer        20     1222.05                13     21263.67
# 357    Net Banking        20      797.61                11     14197.46
#
#      Order_Year  Order_Month  Order_Day
# 182        2025            7         14
# 102        2025            2         17
# 362        2025           12         24
# 173        2025            2          9
# 900        2024           10          1
# ..          ...          ...        ...
# 203        2024            8          4
# 758        2025            5         19
# 130        2024            4         16
# 549        2024            2         24
# 357        2024            5          3
#
# [391 rows x 13 columns]

# %% [markdown]
# ## Task 31
#
# Filter rows where Product_Category belongs to a given list of two categories.

# %%
df[df['Product_Category'].isin(['Stationery', 'Furniture'])]
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 700  10ORD100789 2025-07-21           School     East       Stationery
# 137  10ORD100216 2025-08-22           School  Central        Furniture
# 786  10ORD100954 2025-10-15           School  Central       Stationery
# 954  10ORD100783 2025-02-01          Startup     West        Furniture
# 785  10ORD100225 2024-07-25           School  Central        Furniture
# ..           ...        ...              ...      ...              ...
# 585  10ORD100408 2024-12-11          Startup    North       Stationery
# 375  10ORD100746 2024-03-15           School     West        Furniture
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
# 556  10ORD100370 2024-03-25           School     East       Stationery
# 632  10ORD100284 2025-11-13           School    South        Furniture
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 700    Net Banking         1    24838.88                 3     24093.71
# 137  Bank Transfer         1    24491.38                 7     22776.98
# 786            UPI         1    24135.53                 3     23411.46
# 954  Bank Transfer         1    24110.82                25     18083.11
# 785    Credit Card         1    23660.22                 5     22477.21
# ..             ...       ...         ...               ...          ...
# 585     Debit Card        20     2018.78                22     31492.97
# 375     Debit Card        20     1424.81                22     22227.04
# 357    Net Banking        20      797.61                11     14197.46
# 556    Credit Card        20      707.07                 7     13151.50
# 632    Net Banking        20      541.60                25      8124.00
#
#      Order_Year  Order_Month  Order_Day
# 700        2025            7         21
# 137        2025            8         22
# 786        2025           10         15
# 954        2025            2          1
# 785        2024            7         25
# ..          ...          ...        ...
# 585        2024           12         11
# 375        2024            3         15
# 357        2024            5          3
# 556        2024            3         25
# 632        2025           11         13
#
# [414 rows x 13 columns]

# %% [markdown]
# ## Task 32
#
# Find all unique values in Customer_Segment.

# %%
df["Customer_Segment"].unique()
# Out:
# <StringArray>
# ['School', 'Freelancer', 'Startup', 'Enterprise']
# Length: 4, dtype: str

# %% [markdown]
# ## Task 33
#
# Count the number of unique values in Product_Category.

# %%
df["Product_Category"].nunique()
# Out:
# 5

# %% [markdown]
# ## Task 34
#
# Display value counts for Region.

# %%
df['Region'].value_counts()
# Out:
# Region
# North      211
# Central    206
# South      204
# East       201
# West       178
# Name: count, dtype: int64

# %% [markdown]
# ## Task 35
#
# Display value counts for Payment_Method.

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Net Banking      234
# UPI              198
# Bank Transfer    196
# Credit Card      190
# Debit Card       182
# Name: count, dtype: int64

# %% [markdown]
# ## Task 36
#
# Find the minimum, maximum, and mean of Unit_Price.

# %%
max = df["Unit_Price"].max()
min = df["Unit_Price"].min()
mean = df["Unit_Price"].mean()
print(max,)
print(min)
print(mean)
# Out:
# 24991.95
# 29.21
# 12583.02298

# %% [markdown]
# ## Task 37
#
# Find the total sum of Order_Value.

# %%
df["Order_Value"].sum()
# Out:
# np.float64(56478788.599999994)

# %% [markdown]
# ## Task 38
#
# Find the median of Quantity.

# %%
df["Quantity"].median()
# Out:
# np.float64(3.0)

# %% [markdown]
# ## Task 39
#
# Find the standard deviation of Order_Value.

# %%
df['Order_Value'].std()
# Out:
# np.float64(77616.1462027844)

# %% [markdown]
# ## Task 40
#
# Create a new column Gross_Value as Quantity multiplied by Unit_Price.

# %%
df["Gross_Value"] = df["Quantity"] * df["Unit_Price"]

# %% [markdown]
# ## Task 41
#
# Verify whether Gross_Value and Order_Value are consistent after discount calculation.

# %%
df['Modify_1'] = df['Gross_Value']*(1 - df['Discount_Percent'] /100)

# %%
df['consistent'] = df['Order_Value'].round(2) == df['Modify_1'].round(2)

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 700  10ORD100789 2025-07-21           School     East       Stationery
# 182  10ORD100378 2025-07-14       Freelancer  Central      Electronics
# 137  10ORD100216 2025-08-22           School  Central        Furniture
# 211  10ORD100142 2024-09-20           School     West      Electronics
# 339  10ORD100533 2024-11-22           School    North         Printing
# ..           ...        ...              ...      ...              ...
# 357  10ORD100425 2024-05-03       Freelancer     West       Stationery
# 556  10ORD100370 2024-03-25           School     East       Stationery
# 632  10ORD100284 2025-11-13           School    South        Furniture
# 766  10ORD100374 2024-07-17       Freelancer    North      Electronics
# 4    10ORD100412 2025-06-19       Enterprise     East      Electronics
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 700    Net Banking         1    24838.88                 3     24093.71
# 182    Net Banking         1    24507.86                10     22057.07
# 137  Bank Transfer         1    24491.38                 7     22776.98
# 211  Bank Transfer         1    24436.81                 6     22970.60
# 339  Bank Transfer         1    24377.75                27     17795.76
# ..             ...       ...         ...               ...          ...
# 357    Net Banking        20      797.61                11     14197.46
# 556    Credit Card        20      707.07                 7     13151.50
# 632    Net Banking        20      541.60                25      8124.00
# 766            UPI        20      343.28                21      5423.82
# 4       Debit Card        20      307.87                22      4802.77
#
#      Order_Year  Order_Month  Order_Day  Gross_Value    Modify_1  consistent
# 700        2025            7         21     24838.88  24093.7136        True
# 182        2025            7         14     24507.86  22057.0740        True
# 137        2025            8         22     24491.38  22776.9834        True
# 211        2024            9         20     24436.81  22970.6014        True
# 339        2024           11         22     24377.75  17795.7575        True
# ..          ...          ...        ...          ...         ...         ...
# 357        2024            5          3     15952.20  14197.4580        True
# 556        2024            3         25     14141.40  13151.5020        True
# 632        2025           11         13     10832.00   8124.0000        True
# 766        2024            7         17      6865.60   5423.8240        True
# 4          2025            6         19      6157.40   4802.7720        True
#
# [1000 rows x 16 columns]

# %% [markdown]
# ## Task 42
#
# Create a new column Discount_Amount.

# %%
df['Discount_Amount'] = df['Gross_Value']*df['Discount_Percent']/100
df["Discount_Amount"]
# Out:
# 700     745.1664
# 182    2450.7860
# 137    1714.3966
# 211    1466.2086
# 339    6581.9925
#          ...
# 357    1754.7420
# 556     989.8980
# 632    2708.0000
# 766    1441.7760
# 4      1354.6280
# Name: Discount_Amount, Length: 1000, dtype: float64

# %% [markdown]
# ## Task 43
#
# Create a new column High_Value_Order where Order_Value > 5000 is Yes otherwise No.

# %%
df['High_Value_Order'] = df['Order_Value'].where(df['Order_Value'] > 5000)

# %% [markdown]
# ## Task 44
#
# Use apply() to categorize Unit_Price into Low, Medium, High.

# %%
def category(p):
    if p < 5000:
        return 'Low'
    elif p <= 15000:
        return 'Medium'
    else:
        return 'High'

df["price_category"] = df['Unit_Price'].apply(category)
df["price_category"]
# Out:
# 700    High
# 182    High
# 137    High
# 211    High
# 339    High
#        ...
# 357     Low
# 556     Low
# 632     Low
# 766     Low
# 4       Low
# Name: price_category, Length: 1000, dtype: str

# %% [markdown]
# ## Task 45
#
# Find the top 10 highest Order_Value rows.

# %%
df.nlargest(10, 'Order_Value')
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 427  10ORD100062 2025-11-17       Enterprise  Central      Electronics
# 921  10ORD100035 2024-11-13          Startup     East      Electronics
# 665  10ORD100227 2025-10-18          Startup    South       Stationery
# 386  10ORD100501 2025-07-13          Startup     East      Electronics
# 940  10ORD100841 2024-06-06       Freelancer     East       Stationery
# 920  10ORD100206 2025-01-13       Enterprise    North           Pantry
# 257  10ORD100917 2024-05-30       Enterprise     East      Electronics
# 929  10ORD100898 2025-07-02       Enterprise    North        Furniture
# 961  10ORD100561 2025-09-30          Startup  Central        Furniture
# 765  10ORD100672 2025-03-27       Freelancer    South       Stationery
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 427  Bank Transfer        20    24580.19                 5    467023.61
# 921    Net Banking        20    23755.17                 8    437095.13
# 665  Bank Transfer        20    22317.62                 9    406180.68
# 386    Net Banking        20    20519.62                 3    398080.63
# 940            UPI        20    21601.38                 8    397465.39
# 920     Debit Card        20    24519.25                20    392308.00
# 257     Debit Card        20    22117.54                14    380421.69
# 929    Credit Card        20    23069.39                18    378338.00
# 961            UPI        20    24846.40                25    372696.00
# 765            UPI        20    23565.99                21    372342.64
#
#      Order_Year  Order_Month  Order_Day  Gross_Value    Modify_1  consistent  \
# 427        2025           11         17     491603.8  467023.610        True
# 921        2024           11         13     475103.4  437095.128        True
# 665        2025           10         18     446352.4  406180.684        True
# 386        2025            7         13     410392.4  398080.628        True
# 940        2024            6          6     432027.6  397465.392        True
# 920        2025            1         13     490385.0  392308.000        True
# 257        2024            5         30     442350.8  380421.688        True
# 929        2025            7          2     461387.8  378337.996        True
# 961        2025            9         30     496928.0  372696.000        True
# 765        2025            3         27     471319.8  372342.642        True
#
#      Discount_Amount  High_Value_Order price_category
# 427        24580.190         467023.61           High
# 921        38008.272         437095.13           High
# 665        40171.716         406180.68           High
# 386        12311.772         398080.63           High
# 940        34562.208         397465.39           High
# 920        98077.000         392308.00           High
# 257        61929.112         380421.69           High
# 929        83049.804         378338.00           High
# 961       124232.000         372696.00           High
# 765        98977.158         372342.64           High

# %% [markdown]
# ## Task 46
#
# Find the bottom 10 lowest Order_Value rows.

# %%
df.nsmallest(10, 'Order_Value')
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 618  10ORD100985 2024-01-03       Freelancer  Central           Pantry
# 613  10ORD100713 2025-04-23       Enterprise     East        Furniture
# 413  10ORD100265 2025-04-08          Startup     East         Printing
# 9    10ORD100137 2025-06-11       Enterprise    North           Pantry
# 645  10ORD100470 2024-02-06       Freelancer     East         Printing
# 307  10ORD100577 2025-10-26          Startup  Central         Printing
# 156  10ORD100310 2024-10-04       Freelancer    North        Furniture
# 478  10ORD100606 2025-11-11       Enterprise     West           Pantry
# 243  10ORD100800 2024-09-21       Freelancer    South        Furniture
# 291  10ORD100797 2025-02-10       Freelancer  Central         Printing
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 618    Net Banking         2       29.21                16        49.07
# 613    Net Banking         2       54.65                13        95.09
# 413            UPI         1      180.68                 4       173.45
# 9              UPI         1      249.84                24       189.88
# 645  Bank Transfer         3       83.24                13       217.26
# 307    Net Banking         1      339.62                13       295.47
# 156  Bank Transfer         4      104.26                 2       408.70
# 478    Net Banking         5       98.09                 9       446.31
# 243     Debit Card         1      521.59                12       459.00
# 291  Bank Transfer         1      646.59                23       497.87
#
#      Order_Year  Order_Month  Order_Day  Gross_Value  Modify_1  consistent  \
# 618        2024            1          3        58.42   49.0728        True
# 613        2025            4         23       109.30   95.0910        True
# 413        2025            4          8       180.68  173.4528        True
# 9          2025            6         11       249.84  189.8784        True
# 645        2024            2          6       249.72  217.2564        True
# 307        2025           10         26       339.62  295.4694        True
# 156        2024           10          4       417.04  408.6992        True
# 478        2025           11         11       490.45  446.3095        True
# 243        2024            9         21       521.59  458.9992        True
# 291        2025            2         10       646.59  497.8743        True
#
#      Discount_Amount  High_Value_Order price_category
# 618           9.3472               NaN            Low
# 613          14.2090               NaN            Low
# 413           7.2272               NaN            Low
# 9            59.9616               NaN            Low
# 645          32.4636               NaN            Low
# 307          44.1506               NaN            Low
# 156           8.3408               NaN            Low
# 478          44.1405               NaN            Low
# 243          62.5908               NaN            Low
# 291         148.7157               NaN            Low

# %% [markdown]
# ## Task 47
#
# Group by Region and calculate average Order_Value.

# %%
df.groupby('Region')['Order_Value'].mean()
# Out:
# Region
# Central    55650.628398
# East       60277.689652
# North      55000.510190
# South      61522.144461
# West       49119.766348
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 48
#
# Group by Product_Category and calculate total sales.

# %%
df.groupby('Product_Category')['Order_Value'].sum()
# Out:
# Product_Category
# Electronics    11461964.54
# Furniture      12592458.34
# Pantry          9388883.18
# Printing       10438451.26
# Stationery     12597031.28
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 49
#
# Group by Payment_Method and calculate total Quantity sold.

# %%
df.groupby('Payment_Method')['Quantity'].sum()
# Out:
# Payment_Method
# Bank Transfer     974
# Credit Card      1119
# Debit Card        965
# Net Banking      1276
# UPI               992
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 50
#
# Group by Customer_Segment and calculate average discount percentage.

# %%
df.groupby('Customer_Segment')['Discount_Percent'].mean()
# Out:
# Customer_Segment
# Enterprise    14.696154
# Freelancer    13.693227
# School        13.956693
# Startup       14.042553
# Name: Discount_Percent, dtype: float64

# %% [markdown]
# ## Task 51
#
# Perform multi-level grouping by Region and Product_Category and compute total Order_Value.

# %%
df.groupby(['Region','Product_Category'])['Order_Value'].sum()
# Out:
# Region   Product_Category
# Central  Electronics         2021177.79
#          Furniture           2512922.79
#          Pantry              2190459.51
#          Printing            1922645.41
#          Stationery          2816823.95
# East     Electronics         3568207.32
#          Furniture           1799125.15
#          Pantry              2442482.69
#          Printing            1937645.48
#          Stationery          2368354.98
# North    Electronics         2652235.00
#          Furniture           3484002.57
#          Pantry              1904881.77
#          Printing            1828065.09
#          Stationery          1735923.22
# South    Electronics         2303230.17
#          Furniture           2949158.99
#          Pantry              1244276.20
#          Printing            2900188.34
#          Stationery          3153663.77
# West     Electronics          917114.26
#          Furniture           1847248.84
#          Pantry              1606783.01
#          Printing            1849906.94
#          Stationery          2522265.36
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 52
#
# Aggregate Quantity, Unit_Price, and Order_Value with multiple statistics using agg().

# %%
df.agg({'Quantity': ['sum','mean'],'Unit_Price': ['min','max','mean'],'Order_Value': ['sum','mean']})
# Out:
#       Quantity   Unit_Price   Order_Value
# sum   5326.000          NaN  5.647879e+07
# mean     5.326  12583.02298  5.647879e+04
# min        NaN     29.21000           NaN
# max        NaN  24991.95000           NaN

# %% [markdown]
# ## Task 53
#
# Create a pivot table showing total Order_Value by Region and Payment_Method.

# %% [markdown]
# ## Task 54
#
# Create a pivot table showing average Unit_Price by Product_Category and Customer_Segment.

# %% [markdown]
# ## Task 55
#
# Count the number of orders placed in each month.

# %%
df["Order_Month"].value_counts().sort_index()
# Out:
# Order_Month
# 1      86
# 2      72
# 3      76
# 4      82
# 5      88
# 6      91
# 7      80
# 8     101
# 9      85
# 10     88
# 11     71
# 12     80
# Name: count, dtype: int64

# %% [markdown]
# ## Task 56
#
# Find the month with the highest total sales.

# %%
df.groupby("Order_Month")["Order_Value"].sum().idxmax()
# Out:
# np.int32(6)

# %% [markdown]
# ## Task 57
#
# Find the region with the highest average order value.

# %%
df.groupby("Region")["Order_Value"].mean().idxmax()
# Out:
# 'South'

# %% [markdown]
# ## Task 58
#
# Find the product category with the highest total quantity sold.

# %% [markdown]
# ## Task 59
#
# Use query() to filter rows where Quantity >= 2 and Discount_Percent >= 15.

# %% [markdown]
# ## Task 60
#
# Select only Order_ID, Region, Product_Category, and Order_Value columns.

# %% [markdown]
# ## Task 61
#
# Reorder the columns in any meaningful custom order.

# %% [markdown]
# ## Task 62
#
# Find rows where Order_Value is above the overall average order value.

# %% [markdown]
# ## Task 63
#
# Find rows where Unit_Price is below the 25th percentile.

# %% [markdown]
# ## Task 64
#
# Find the correlation between Quantity, Unit_Price, Discount_Percent, and Order_Value.

# %% [markdown]
# ## Task 65
#
# Export the top 50 highest value orders to a CSV file.

# %% [markdown]
# ## Task 66
#
# Create a bar chart of total Order_Value by Region using Matplotlib.

# %% [markdown]
# ## Task 67
#
# Create a bar chart of total Quantity sold by Product_Category using Seaborn.

# %% [markdown]
# ## Task 68
#
# Create a histogram of Unit_Price using Matplotlib.

# %% [markdown]
# ## Task 69
#
# Create a histogram of Order_Value with KDE using Seaborn.

# %% [markdown]
# ## Task 70
#
# Create a boxplot of Order_Value by Region.

# %% [markdown]
# ## Task 71
#
# Create a boxplot of Unit_Price by Payment_Method.

# %% [markdown]
# ## Task 72
#
# Create a countplot of Customer_Segment.

# %% [markdown]
# ## Task 73
#
# Create a pie chart of Payment_Method distribution.

# %% [markdown]
# ## Task 74
#
# Create a line chart of monthly total sales.

# %% [markdown]
# ## Task 75
#
# Create a heatmap of correlation among numerical columns.

# %% [markdown]
# ## Task 76
#
# Create a scatter plot of Unit_Price vs Order_Value.

# %% [markdown]
# ## Task 77
#
# Create a scatter plot of Quantity vs Order_Value colored by Region using Seaborn.

# %% [markdown]
# ## Task 78
#
# Create a violin plot of Order_Value by Product_Category.

# %% [markdown]
# ## Task 79
#
# Create a stacked bar style plot of monthly sales by Region.

# %% [markdown]
# ## Task 80
#
# Create a pairplot for Quantity, Unit_Price, Discount_Percent, and Order_Value.
